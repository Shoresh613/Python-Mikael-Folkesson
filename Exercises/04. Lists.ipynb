# %% [markdown]
# ## 1. Dice rolls (*)
#
# Simulate 10 dice rolls and **append** the rolls to a list or use **list comprehension**.
#
# &nbsp; a) &nbsp; sort the list in **ascending** order (*)
#
# &nbsp; b) &nbsp; sort the list in **descending** order (*)
#
# &nbsp; c) &nbsp; find the **maximum** and **minimum** value in the list (*)
#
#
# <details>
#
# <summary>Answer </summary>
#
# a)
# ```
# Ascending order: [1, 1, 2, 3, 4, 4, 4, 5, 6, 6]
# ```
#
# b)
# ```
# Descending order: [6, 6, 5, 4, 4, 4, 3, 2, 1, 1]
# ```
#
# c)
# ```
# Maximum: 6
# Minimum: 1
# ```
#
# </details>

# %%
# all three in one

import random

dicerolls = []

for i in range(10):
    dicerolls.append(random.randint(1,6))

print(f"Unsorted: {dicerolls}")
dicerolls.sort()
print(f"Sorted in ascending order: {dicerolls}")
dicerolls.sort(reverse=True)
print(f"Sorted in descending order: {dicerolls}")

print(f"Maximum: {max(dicerolls)}, Minimum: {min(dicerolls)}")

# %% [markdown]
# ---
# ## 2. Food menu (*)
#
# Create a:
#
# &nbsp; a) &nbsp; **list** with the following elements: "vegetarisk lasagne", "spaghetti", "fisk", "grönsakssoppa", "pannkakor". (*)
#
# &nbsp; b) &nbsp; **list** with the weekdays (*)
#
# &nbsp; c) &nbsp; create a food menu with each day corresponding to each food item and print it out. (*)
#
# <details>
#
# <summary>Answer</summary>
#
# c)
# ```
# Bambameny
# Mån: vegetarisk lasagne
# Tis: spaghetti
# Ons: fisk
# Tor: grönsakssoppa
# Fre: pannkakor
# ```
#
# </details>

# %%
dishes = ["vegetarisk lasagne", "spaghetti", "fisk", "grönssakssoppa", "pannkakor"]

weekdays = ["Måndag", "Tisdag", "Onsdag", "Torsdag", "Fredag"]

i=0
while i<len(dishes):
    print(f"{weekdays[i]:>8}: {str.capitalize(dishes[i])}")
    i+=1

# %% [markdown]
# ---
# ## 3. Squares (*)
#
# &nbsp; a) &nbsp; Use **list comprehension** to create a list of squares from -10 to 10 (*)
#
# &nbsp; a) &nbsp; Plot this list using **matplotlib**. (*)
#
# <details>
#
# <summary>Answer</summary>
#
# a)
# ```
# [100, 81, 64, 49, 36, 25, 16, 9, 4, 1, 0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# ```
#
# b)
#
# <img align="left" src="../Assets/x^2_graph.png" width="300"/>
# </details>

# %%
import matplotlib.pyplot as plt

squares = [item**2 for item in range(-10,10)]

# Create a figure and a subplot
fig, ax = plt.subplots()

# Plot the data points
ax.plot(squares)

# Add labels and titles to the plot
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_title("Plot of a List of Squares")

# Show the plot
plt.show()

# %% [markdown]
# ---
# ## 4. Chessboard (**)
#
# &nbsp; a) &nbsp; Create this list using **list comprehension**: (*)
#
# ```python
# ['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1']
# ```
#
# &nbsp; b) &nbsp; Create a 2D list to hold the coordinates in a chessboard. (**)
#
# <details>
#
# <summary>Hint</summary>
#
# b) Use **f-string** and create a list of characters with:
#
# ```python
# list("ABCDEFGH)
# ```
#
# b) One option is to use nested list comprehension where one for-loop creates the first list and the other creates several of the first list
#
# </details>
#
#
# <details>
#
# <summary>Answer</summary>
#
# b)
# ```
# [['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1'],
#  ['A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2'],
#  ['A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3'],
#  ['A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4'],
#  ['A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5'],
#  ['A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6'],
#  ['A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7'],
#  ['A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8']]
# ```
#
# </details>

# %%
chessboard = []
for i in range(1,9):
    chessboard.append([(letter + str(i)) for letter in list("ABCDEFGH")])

for i in range(8):
    print()
    for j in range(8):
        print(chessboard[i][j], end=" ")

# %% [markdown]
# ---
# ## 5. Dice rolls convergence (**)
#
# Simulate:
#
# &nbsp; a) &nbsp; 100 dice rolls and count the number of outcome six. (*)
#
# &nbsp; b) &nbsp; 10, 100, 1000, 10000, 100000, 1000000 dice rolls. Count the number of outcome six in each simulation and store it in a list. Compute the probability of outcome six in each simulation. (**)
#
# &nbsp; c) &nbsp; Use matplotlib to plot this list. (*)
#
# <details>
#
# <summary>Hint </summary>
#
# Use this code for plot settings:
#
# ```python
# plt.plot(probability_six, '-*')
# plt.title("Probability of six for different number of rolls")
# plt.xticks([0,1,2,3,4,5], num_rolls);
# plt.xlabel("Number of dice rolls")
# plt.ylabel("Probability")
#
# ```
# </details>
#
# <details>
#
# <summary>Answer </summary>
#
# a)
# ```
# The number of outcome six in 100 dice rolls is: 17
# ```
#
# b)
# ```
# Count number of six: [1, 21, 161, 1642, 16560, 166406]
# P(six) = [0.1, 0.21, 0.161, 0.1642, 0.1656, 0.1664]
# ```
#
# c) Note that the graph changes due to random simulation. To reproduce this result, use
#
# ```python
# random.seed(1)
# ```
#
# <img align="left" src="../Assets/probability_six_graph.png" width="300"/>
#
# </details>

# %%
import random
import matplotlib.pyplot as plt

sixes = []
random.seed(1)

for i in range(1,7):
    dice_rolls = []
    for roll in range(10**i):
        dice_rolls.append(random.randint(1,6))
    print(f"The number of outcome 6 in {10**i} dice rolls: {dice_rolls.count(6)}, {(dice_rolls.count(6)/10**i):.2%}")
    sixes.append(dice_rolls.count(6)/10**i)

print(f"Probability P of sixes list: {sixes}")

# Create a figure and a subplot
fig, ax = plt.subplots()

# Plot the data points
ax.plot(sixes)

# Add labels and titles to the plot
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_title("Plot probability of sixes for 10^(x+1) rolls")

# Show the plot
plt.show()
# Out:
# The number of outcome 6 in 10 dice rolls: 1, 10.00%
# The number of outcome 6 in 100 dice rolls: 21, 21.00%
# The number of outcome 6 in 1000 dice rolls: 161, 16.10%
# The number of outcome 6 in 10000 dice rolls: 1642, 16.42%
# The number of outcome 6 in 100000 dice rolls: 16560, 16.56%
# The number of outcome 6 in 1000000 dice rolls: 166406, 16.64%
# Probability P of sixes list: [0.1, 0.21, 0.161, 0.1642, 0.1656, 0.166406]

# %% [markdown]
# ---
# ## 6. Monte Carlo simulation (**)
#
# &nbsp; a) Simulate 5000 uniformly distributed points between -1 and 1, $X\sim U(-1,1)$. Now calculate the Euclidean distances between each point and the origin (0,0), $d_i = \sqrt{x_i^2 + y_i^2}$. For $d_i < 1$ plot the point with one color, and for $d_i > 1$ plot the point in another color, $i = \{1,\ldots, 5000\}$.  (**)
#
# &nbsp; b) Calculate the fraction between number of inner points and number of outer points. What do you this will converge to when number of points reaches infinity? (**)
#
#
# <details>
#
# <summary>Hint</summary>
#
# a)
#
# Try solve this task with pen and paper before approaching to code it.
#
# b)
#
# Think in terms of theoretical areas. Also try to increase the number of simulated points, to see if you find convergence.
#
# </details>
#
# <details>
#
# <summary>Answer</summary>
#
#
# a)
#
# <img src="../Assets/MC_simulation_5k.png" width = 300>
#
#
# b)
#
# 0.7908
#
# No answer here, try to prove it theoretically.
#
#
# </details>

# %%
import math
import random
import matplotlib.pyplot as plt

x_list = []
y_list = []
number_of_dots = 100000

for i in range(number_of_dots):
    x_list.append(random.random()*2-1)
    y_list.append(random.random()*2-1)

print(f"n = {len(x_list):,.0f}")

def get_distance_origo(x,y):
    return math.sqrt(x**2 + y**2)

distance_list = []

for i in range(number_of_dots):
    distance_list.append(get_distance_origo(x_list[i],y_list[i]))

colors = ['red' if i > 1 else 'blue' for i in distance_list]

print(f"Fraction of blue/red points: {colors.count('blue') / colors.count('red')}, red/blue points: {colors.count('red') / colors.count('blue')}")
print(f"The fraction of blue points compared to all points: {colors.count('blue')/number_of_dots}")
print(f"\nThe fraction of blue points should converge to {math.pi/4 = },\nas the area of the square is 4, and the area of the circle is Pi.")

# Create a figure and a subplot
fig, ax = plt.subplots()

# Plot the data points
ax.scatter(x_list,y_list,c=colors)

# Add labels and titles to the plot
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_title("Random points in 2D space between -1 and 1 x,y")

# Show the plot
plt.axis('equal')
plt.show()
# Out:
# n = 100,000
# Fraction of blue/red points: 3.6737707982800525, red/blue points: 0.2721998880464099
# The fraction of blue points compared to all points: 0.78604
#
# The fraction of blue points should converge to math.pi/4 = 0.7853981633974483,
# as the area of the square is 4, and the area of the circle is Pi.

# %% [markdown]
# ---
# ## 7. A cute rabbit among two ferocious snakes (**)
#
# There are three identical doors, behind two of them, there are ferocious snakes and behind one of them is a cute little rabbit. Your aim is to pick a door and get the cute rabbit. You start picking one door randomly and suddenly another door opens and snake slithers away *pssss*. Now you have a choice to either stay with your door or change to the remaining door.
#
# &nbsp; a) What is your choice and why? (**)
#
# &nbsp; b) Randomly assign which door has the rabbit, and randomly pick an initial door. Now simulate 10, 100, 1000, 10000, 100000, 1000000 times for staying and for switching doors. Calculate the proportion of finding the rabbits for each set of simulations. Plot the results (**)
#
#
# <details>
#
# <summary>Hint</summary>
#
# a)
#
# Try to reason using probability.
#
#
# </details>
#
# <details>
#
# <summary>Answer</summary>
#
#
# a)
#
# You will simulate the answer in b).
#
# b)
#
# <img src="../Assets/mh_simulations.png" width = 300>
#
#
#
# </details>

# %%
import random

print("My choice is to change to the other door, as in the first case \nthe probability of getting it right is 1/3, \nbut after the snake left it is now 1/2.\n")

# Randomizes the animals behind the doors
def get_three_doors():
    for i in range(3):
        animals = ["snake", "rabbit", "snake"]
        doors = []
        first_animal_index = random.randint(0,2)
        doors.append(animals[first_animal_index])
        del(animals[first_animal_index])
        second_animal_index = random.randint(0,1)
        doors.append(animals[second_animal_index]) 
        del(animals[second_animal_index])
        doors.append(animals[0]) 
        return doors    

def get_set_of_doors(n):
    set_of_doors = []
    for i in range(n):
        set_of_doors.append(get_three_doors())
    return set_of_doors

doorsets = []
n=4
for i in range(1,n):
    doorsets.append(get_set_of_doors(10**i))

print(doorsets)
print(len(doorsets[-1]))

results_list_stay = [[],[],[],[],[],[]]
results_list_switch = [[],[],[],[],[],[]]

for i in range(n+1):
    print(doorsets)
    for door_row in doorsets[i]:
        chosen_door = random.randint(0,2)

        while(True):
            possible_snake_door = random.randint(0,2)
            if door_row[possible_snake_door] == "snake":
                if possible_snake_door != chosen_door:
                    # stay
                    if door_row[chosen_door] == "snake":
                        results_list_stay[i].append("Loose")
                    elif door_row[chosen_door] == "rabbit":
                        results_list_stay[i].append("Win")
                    
                    # Switch to other
                    if chosen_door == 0 and possible_snake_door == 1:
                        chosen_door == 2
                    elif chosen_door == 0 and possible_snake_door == 2:
                        chosen_door == 1
                    if chosen_door == 1 and possible_snake_door == 0:
                        chosen_door == 2
                    elif chosen_door == 1 and possible_snake_door == 2:
                        chosen_door == 0                    
                    if chosen_door == 2 and possible_snake_door == 0:
                        chosen_door == 1
                    elif chosen_door == 2 and possible_snake_door == 1:
                        chosen_door == 0

                    if door_row[chosen_door] == "snake":
                        results_list_switch[i].append("Loose")
                    elif door_row[chosen_door] == "rabbit":
                        results_list_switch[i].append("Win")
                    break
print(results_list_stay)
# Out:
# My choice is to change to the other door, as in the first case
# the probability of getting it right is 1/3,
# but after the snake left it is now 1/2.
#
# ...

# %%
# Nytt försök, Monty Hall problem

import random

print("""My choice is to change to the other door, as in the first case 
the probability of getting it right is 1/3, 
but after the snake left it is now 1/2. (Or so I thought)\n""")

# Randomizes the animals behind the doors

def get_doors():
    random_animals =["snake", "rabbit", "snake"]
    random.shuffle(random_animals)
    return random_animals

n=1000000
results = []

def get_results_for_n(n):
    staying_rights=0
    for i in range(n):
        doors=get_doors()
        chosen_door=random.randint(0,2)
        # # host shows one of the snakes
        # if chosen_door==0:
        #     if doors[1]=="snake":
        #         not_available_door=1
        #     else:
        #         not_available_door=2
        # elif chosen_door==1:
        #     if doors[0]=="snake":
        #         not_available_door=0
        #     else:
        #         not_available_door=2
        # elif chosen_door==2:
        #     if doors[1]=="snake":
        #         not_available_door=1
        #     else:
        #         not_available_door=0

        if doors[chosen_door] == "rabbit":
            staying_rights +=1
    return staying_rights

for i in range(1,7):
    results.append(get_results_for_n(10**i))
for j, result in enumerate(results):
    print(f"{10**(j+1):,} runs")
    print(f"{'':=^11}")
    print(f"Rights in staying: {results[j]:,}")
    print(f"Rights in switching: {10**(j+1)-results[j]:,}\n")
# Out:
# My choice is to change to the other door, as in the first case
# the probability of getting it right is 1/3,
# but after the snake left it is now 1/2. (Or so I thought)
#
# 10 runs
# ...
# Rights in staying: 4
# Rights in switching: 6
#
# 100 runs
# ...
# Rights in staying: 39
# Rights in switching: 61
#
# 1,000 runs
# ...
# Rights in staying: 338
# Rights in switching: 662
#
# 10,000 runs
# ...
# Rights in staying: 3,236
# Rights in switching: 6,764
#
# 100,000 runs
# ...
# Rights in staying: 33,145
# Rights in switching: 66,855
#
# 1,000,000 runs
# ...
# Rights in staying: 333,545
# Rights in switching: 666,455
